# %% [markdown]
# # LangChain (open source): Memory
#
# ### Outline
# - `ChatHistory`: keep everything (the `ConversationBufferMemory` equivalent)
# - `WindowChatHistory`: keep only the last k exchanges (`ConversationBufferWindowMemory`)
# - `TokenBufferChatHistory`: keep what fits a token budget (`ConversationTokenBufferMemory`)
# - `SummaryBufferChatHistory`: summarize the overflow (`ConversationSummaryBufferMemory`)
#
# Open-source recode of `02-LangChain-for-LLM-Application-Development/L2-Memory.ipynb`.
# `ConversationChain` and every `ConversationXMemory` class were removed - modern LangChain has no
# "memory object" abstraction at all. The replacement, for a plain conversation with no tool calls,
# is simply: manage a `list[BaseMessage]` yourself and decide what to keep before each call. This
# notebook recodes the same four strategies as small classes over that list, so the actual
# behavioral differences are still visible side by side.
#
# Token counts below are a `len(text) // 4` approximation, not `tiktoken` - that library counts
# OpenAI's specific tokenizer, which has no bearing on how the Ollama-hosted model actually
# tokenizes text. It's good enough to demonstrate "trim when the budget is exceeded."

# %% [markdown]
# ## Setup
#
# This notebook is the open-source / Ollama-cloud recode of the matching lesson in
# [`openai_agentic_ai_course`](../../openai_agentic_ai_course/), reusing the shared
# `common.py` / `tracing.py` helpers already built for
# [`open_source_agentic_ai_course`](../../open_source_agentic_ai_course/) rather than duplicating them here.
#
# - **Model**: `ChatOllama`, pointed at the Ollama cloud endpoint configured in the
#   repo-root `.env` (`OLLAMA_MODEL` / `OLLAMA_BASE_URL` / `OLLAMA_API_KEY`).
# - **Tracing**: every `.invoke()` / `.batch()` / `.stream()` call below passes
#   `config=traced("run name")`, which attaches a Langfuse callback - open the
#   Langfuse dashboard and filter by trace name to see this notebook's calls.
# - **Kernel**: run this with the repo's `.venv` (`Python 3 (ipykernel)`) - it already
#   has everything in [`requirements.txt`](../../requirements.txt) installed.

# %%
import sys
from pathlib import Path

# common.py / tracing.py live in open_source_agentic_ai_course/, not here - add it to sys.path
# instead of copying them, so this notebook always uses the one shared implementation.
COURSE_DIR = Path("../../open_source_agentic_ai_course").resolve()
if str(COURSE_DIR) not in sys.path:
    sys.path.insert(0, str(COURSE_DIR))

from common import get_model, traced
from langchain_core.messages import AIMessage, BaseMessage, HumanMessage, SystemMessage

# %%
SYSTEM_PROMPT = (
    "The following is a friendly conversation between a human and an AI. "
    "The AI is talkative and provides lots of specific details from its context."
)


def approx_tokens(text: str) -> int:
    return max(1, len(text) // 4)

# %% [markdown]
# ## `ConversationBufferMemory` equivalent
#
# Keeps every message, forever.

# %%
class ChatHistory:
    """Base strategy: keep everything."""

    def __init__(self):
        self.messages: list[BaseMessage] = []

    def save_context(self, human_input: str, ai_output: str) -> None:
        self.messages.append(HumanMessage(content=human_input))
        self.messages.append(AIMessage(content=ai_output))

    def load_memory_variables(self) -> list[BaseMessage]:
        return list(self.messages)


def converse(model, history: ChatHistory, user_input: str, run_name: str) -> str:
    """The `ConversationChain.predict(input=...)` equivalent: load history, call the model, save the turn."""
    messages = [
        SystemMessage(content=SYSTEM_PROMPT),
        *history.load_memory_variables(),
        HumanMessage(content=user_input),
    ]
    response = model.invoke(messages, config=traced(run_name))
    history.save_context(user_input, response.content)
    return response.content


model = get_model()

# %%
history = ChatHistory()
print(converse(model, history, "Hi, my name is Andrew", "L2: buffer turn 1"))
# Out:
# Hey there, Andrew! 👋 It’s great to meet you. I’m your friendly neighborhood AI, always ready to chat, answer questions, or dive into whatever topic sparks your curiosity.
#
# So, Andrew—what’s on your mind today? Are you a tech enthusiast, a bookworm, a foodie, or maybe a budding musician? Maybe you’re planning a trip, working on a project, or just looking for a good movie recommendation. Whatever it is, I’m here to help, and I love getting to know the people I chat with.
#
# If you’d like, tell me a bit about yourself: where you’re from, what you enjoy doing in your free time, or any cool hobbies you’ve picked up recently. The more details you share, the more tailored and fun our conversation can be. Looking forward to hearing all about you! 🚀

# %%
print(converse(model, history, "What is 1+1?", "L2: buffer turn 2"))
# Out:
# 1 + 1 = 2.

# %%
print(converse(model, history, "What is my name?", "L2: buffer turn 3"))
# expected: it remembers "Andrew" - nothing has been dropped
# Out:
# Your name is Andrew.

# %%
for m in history.load_memory_variables():
    print(f"{type(m).__name__}: {m.content}")
# Out:
# HumanMessage: Hi, my name is Andrew
# AIMessage: Hey there, Andrew! 👋 It’s great to meet you. I’m your friendly neighborhood AI, always ready to chat, answer questions, or dive into whatever topic sparks your curiosity.
#
# So, Andrew—what’s on your mind today? Are you a tech enthusiast, a bookworm, a foodie, or maybe a budding musician? Maybe you’re planning a trip, working on a project, or just looking for a good movie recommendation. Whatever it is, I’m here to help, and I love getting to know the people I chat with.
#
# If you’d like, tell me a bit about yourself: where you’re from, what you enjoy doing in your free time, or any cool hobbies you’ve picked up recently. The more details you share, the more tailored and fun our conversation can be. Looking forward to hearing all about you! 🚀
# HumanMessage: What is 1+1?
# AIMessage: 1 + 1 = 2.
# HumanMessage: What is my name?
# AIMessage: Your name is Andrew.

# %% [markdown]
# The raw building blocks, without going through the model - `save_context` /
# `load_memory_variables` directly, same as the original notebook's manual memory demo.

# %%
history = ChatHistory()
history.save_context("Hi", "What's up")
history.save_context("Not much, just hanging", "Cool")
for m in history.load_memory_variables():
    print(f"{type(m).__name__}: {m.content}")
# Out:
# HumanMessage: Hi
# AIMessage: What's up
# HumanMessage: Not much, just hanging
# AIMessage: Cool

# %% [markdown]
# ## `ConversationBufferWindowMemory` equivalent
#
# Keeps only the last `k` exchanges - everything older falls off.

# %%
class WindowChatHistory(ChatHistory):
    """Keep only the last `k` exchanges."""

    def __init__(self, k: int):
        super().__init__()
        self.k = k

    def load_memory_variables(self) -> list[BaseMessage]:
        return self.messages[-2 * self.k :]


history = WindowChatHistory(k=1)
converse(model, history, "Hi, my name is Andrew", "L2: window turn 1")
converse(model, history, "What is 1+1?", "L2: window turn 2")
print(converse(model, history, "What is my name?", "L2: window turn 3"))
# expected: it won't know - only the 1+1 exchange survived the k=1 window
# Out:
# I’m not sure what your name is—could you let me know?

# %% [markdown]
# ## `ConversationTokenBufferMemory` equivalent
#
# Keeps as many of the most recent messages as fit under a token budget.

# %%
class TokenBufferChatHistory(ChatHistory):
    """Keep as many of the most recent messages as fit under `max_tokens` (approx)."""

    def __init__(self, max_tokens: int):
        super().__init__()
        self.max_tokens = max_tokens

    def load_memory_variables(self) -> list[BaseMessage]:
        kept: list[BaseMessage] = []
        total = 0
        for message in reversed(self.messages):
            cost = approx_tokens(message.content)
            if total + cost > self.max_tokens:
                break
            kept.append(message)
            total += cost
        return list(reversed(kept))


history = TokenBufferChatHistory(max_tokens=15)
history.save_context("AI is what?!", "Amazing!")
history.save_context("Backpropagation is what?", "Beautiful!")
history.save_context("Chatbots are what?", "Charming!")
for m in history.load_memory_variables():
    print(f"{type(m).__name__}: {m.content}")
# expected: only the most recent exchange fits under a ~15 token budget
# Out:
# HumanMessage: Backpropagation is what?
# AIMessage: Beautiful!
# HumanMessage: Chatbots are what?
# AIMessage: Charming!

# %% [markdown]
# ## `ConversationSummaryBufferMemory` equivalent
#
# Once the buffer overflows the token budget, the oldest exchanges get summarized away by an LLM
# call instead of being dropped outright - so old context survives in compressed form.

# %%
class SummaryBufferChatHistory(ChatHistory):
    """Once the buffer overflows `max_tokens`, summarize the oldest exchanges away."""

    def __init__(self, model, max_tokens: int):
        super().__init__()
        self.model = model
        self.max_tokens = max_tokens
        self.summary = ""

    def save_context(self, human_input: str, ai_output: str) -> None:
        super().save_context(human_input, ai_output)
        self._compress_if_needed()

    def _compress_if_needed(self) -> None:
        total = sum(approx_tokens(m.content) for m in self.messages) + approx_tokens(self.summary)
        if total <= self.max_tokens or len(self.messages) <= 2:
            return
        to_summarize, self.messages = self.messages[:-2], self.messages[-2:]
        transcript = "\n".join(
            f"{'Human' if isinstance(m, HumanMessage) else 'AI'}: {m.content}" for m in to_summarize
        )
        prompt = (
            "Progressively summarize the lines of conversation provided, adding onto "
            f"the previous summary and returning a new summary.\n\n"
            f"Current summary:\n{self.summary or '(none yet)'}\n\n"
            f"New lines of conversation:\n{transcript}\n\n"
            "New summary:"
        )
        self.summary = self.model.invoke(
            prompt, config=traced("L2: summary buffer compaction")
        ).content


    def load_memory_variables(self) -> list[BaseMessage]:
        history: list[BaseMessage] = []
        if self.summary:
            history.append(SystemMessage(content=f"Summary of earlier conversation:\n{self.summary}"))
        return history + self.messages

# %%
schedule = (
    "There is a meeting at 8am with your product team. "
    "You will need your powerpoint presentation prepared. "
    "9am-12pm have time to work on your LangChain project which will go quickly "
    "because Langchain is such a powerful tool. At Noon, lunch at the italian "
    "restaurant with a customer who is driving from over an hour away to meet you "
    "to understand the latest in AI. Be sure to bring your laptop to show the "
    "latest LLM demo."
)

history = SummaryBufferChatHistory(model, max_tokens=100)
history.save_context("Hello", "What's up")
history.save_context("Not much, just hanging", "Cool")
history.save_context("What is on the schedule today?", schedule)
print("summary so far:", history.summary or "(not compacted yet)")
# Out:
# summary so far: New summary: Human greets the AI; the AI asks how they’re doing; Human replies that they’re just hanging out; the AI responds with “Cool.”

# %%
for m in history.load_memory_variables():
    print(f"{type(m).__name__}: {m.content[:200]}")
# Out:
# SystemMessage: Summary of earlier conversation:
# New summary: Human greets the AI; the AI asks how they’re doing; Human replies that they’re just hanging out; the AI responds with “Cool.”
# HumanMessage: What is on the schedule today?
# AIMessage: There is a meeting at 8am with your product team. You will need your powerpoint presentation prepared. 9am-12pm have time to work on your LangChain project which will go quickly because Langchain is s

# %%
print(converse(model, history, "What would be a good demo to show?", "L2: summary buffer turn"))
# Out:
# ### A “Show‑and‑Tell” Demo that Will Impress Your Customer
#
# | Goal | Why it’s compelling | What you’ll actually do |
# |------|---------------------|------------------------|
# | **Domain‑specific Q&A** | Shows that your LLM can *understand* and *retrieve* the right facts, not just hallucinate. | Build a LangChain chatbot that pulls answers from your product docs, knowledge base, and a live API (e.g., your pricing calculator). |
# | **Chain of Thought (CoT)** | Demonstrates transparency and the ability to debug or audit the model’s reasoning. | Enable CoT prompting so the model writes out its reasoning before giving the final answer. |
# | **Real‑time API Integration** | Highlights that your system can do more than just text generation – it can act. | Add a small “order‑status” API call that the bot can invoke to fetch live data. |
# | **Custom Prompt Engineering** | Shows you can tailor the LLM to your brand voice and compliance needs. | Use a prompt template that injects your brand guidelines and a compliance disclaimer. |
# | **Interactive UI** | Makes the demo feel like a real product, not a static script. | Use a lightweight web UI (Streamlit or Gradio) that lets the customer type questions and see the bot’s response in real time. |
#
# ---
#
# ## Step‑by‑Step Demo Build (≈ 30 min)
#
# | Time | Action | Code Snippet (Python) |
# |------|--------|-----------------------|
# | **0‑5 min** | **Set up the environment** | ```bash\npip install langchain==0.2.0 openai streamlit\n``` |
# | **5‑10 min** | **Load your knowledge base** | ```python\nfrom langchain.vectorstores import FAISS\nfrom langchain.embeddings import OpenAIEmbeddings\nfrom langchain.text_splitter import RecursiveCharacterTextSplitter\n\nembeddings = OpenAIEmbeddings(openai_api_key=YOUR_KEY)\n\n# Assume you have a folder `docs/` with PDFs/Markdown\nfrom pathlib import Path\ntext = \"\\n\".join([p.read_text() for p in Path(\"docs\").glob(\"*.md\")])\n\nsplitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)\ndocs = splitter.split_text(text)\n\nvector_store = FAISS.from_texts(docs, embeddings)\n``` |
# | **10‑15 min** | **Create the retrieval chain** | ```python\nfrom langchain.chains import RetrievalQA\nfrom langchain.llms import OpenAI\n\nllm = OpenAI(temperature=0.2, model_name=\"gpt-4o\")\nqa_chain = RetrievalQA.from_chain_type(\n    llm=llm,\n    chain_type=\"stuff\",\n    retriever=vector_store.as_retriever(search_kwargs={\"k\": 3}),\n    return_source_documents=True,\n)\n``` |
# | **15‑20 min** | **Add Chain‑of‑Thought prompt** | ```python\nfrom langchain.prompts import PromptTemplate\n\ncoT_template = PromptTemplate(\n    input_variables=[\"question\"],\n    template=\"You are a helpful assistant. First think step‑by‑step, then answer the question: {question}\"\n)\n\nqa_chain = RetrievalQA.from_chain_type(\n    llm=llm,\n    chain_type=\"stuff\",\n    retriever=vector_store.as_retriever(search_kwargs={\"k\": 3}),\n    prompt=coT_template,\n    return_source_documents=True,\n)\n``` |
# | **20‑25 min** | **Add a live API call** | ```python\nimport requests\n\ndef get_order_status(order_id):\n    resp = requests.get(f\"https://api.yourcompany.com/orders/{order_id}\")\n    return resp.json()\n\n# Wrap in a LangChain tool\nfrom langchain.tools import Tool\n\norder_tool = Tool(\n    name=\"OrderStatus\",\n    func=lambda order_id: str(get_order_status(order_id)),\n    description=\"Use this to get the status of an order by ID.\"\n)\n\n# Add to the chain (if you use LLM with tool calling)\nfrom langchain.agents import initialize_agent, AgentType\n\nagent = initialize_agent(\n    tools=[order_tool],\n    llm=llm,\n    agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,\n    verbose=True,\n)\n``` |
# | **25‑30 min** | **Build a quick UI** | ```python\nimport streamlit as st\n\nst.title(\"Product Knowledge Bot\")\nquestion = st.text_input(\"Ask me anything about our product:\")\nif question:\n    with st.spinner(\"Thinking…\"):\n        result = qa_chain.run(question)\n    st.write(result)\n``` |
#
# ---
#
# ## How to Run the Demo
#
# 1. **Clone the repo** (or copy the script into a new file `demo.py`).
# 2. **Set your OpenAI key** in an environment variable: `export OPENAI_API_KEY=sk-…`.
# 3. **Place your product docs** in `docs/` (PDF, Markdown, or plain text).
# 4. **Run**: `streamlit run demo.py`.
# 5. **Open** the local URL (usually `http://localhost:8501`) and start typing questions.
#
# ---
#
# ## What to Highlight During the Demo
#
# | Feature | Talking Point |
# |---------|---------------|
# | **Fast Retrieval** | “The bot pulls the most relevant 3 chunks from our knowledge base in milliseconds.” |
# | **CoT Transparency** | “You can see the model’s reasoning before it gives the final answer.” |
# | **Live API** | “If you ask about an order, the bot will call our real API and return the current status.” |
# | **Custom Prompt** | “We’ve tailored the prompt to match your brand voice and compliance guidelines.” |
# | **Scalability** | “The same architecture can be deployed on a serverless platform or in a container.” |
#
# ---
#
# ## Quick Checklist Before Lunch
#
# - [ ] **Docs**: Make sure the `docs/` folder contains up‑to‑date product information.
# - [ ] **API Key**: Verify your OpenAI key works (`openai.ChatCompletion.create(...)`).
# - [ ] **API Endpoint**: Test the `get_order_status` function manually to confirm it returns JSON.
# - [ ] **UI**: Run `streamlit run demo.py` and confirm the interface loads.
# - [ ] **Backup**: Have a PDF version of the same demo ready in case the laptop fails.
#
# ---
#
# ### Final Thought
#
# A demo that *answers* a customer’s question, *shows* how it got that answer, and *acts* on live data will leave a lasting impression. It demonstrates that your team can build intelligent, trustworthy, and brand‑aligned AI solutions—exactly what your customer is looking for. Good luck, and enjoy the lunch!

# %%
history.summary
# Out:
# 'New summary: Human greets the AI, the AI asks how they’re doing, Human says they’re just hanging out, the AI says “Cool.” Human then asks what’s on the schedule today, and the AI outlines the day: a meeting at 8\u202fam with the product team (needs a PowerPoint), 9\u202fam‑12\u202fpm to work on a LangChain project, and a noon lunch at an Italian restaurant with a customer traveling over an hour away to discuss AI, reminding the Human to bring a laptop for an LLM demo.'
